# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
print("hello world")
# Out:
# hello world
