# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import matplotlib.colors as colors
import xarray as xr
import cartopy as ccrs

# %%
fileName = r"C:\Users\justi\OneDrive\Documents\GEOL_415\Project\query.csv"
pd.read_csv(fileName)
# Out:
#                            time  latitude  longitude    depth  mag magType  \
# 0      2026-09-17T14:19:53.164Z   52.7648  -171.2949  111.666  6.5     mww
# 1      2026-09-11T21:23:55.907Z   -4.9832   106.8742  372.000  6.5     mww
# 2      2026-09-03T11:17:24.056Z   52.2579  -169.4088   35.000  6.3     mww
# 3      2026-09-02T23:46:57.617Z  -56.2062   -27.9085  125.905  6.2     mww
# 4      2026-08-27T21:07:38.352Z   13.2654    50.5425   10.000  6.0     mww
# ...                         ...       ...        ...      ...  ...     ...
# 14676  1692-06-07T16:50:00.000Z   18.0000   -76.5000      NaN  7.5      mw
# 14677  1690-04-16T20:00:00.000Z   17.0800   -62.5100      NaN  7.5    mint
# 14678  1663-02-05T22:30:00.000Z   47.6000   -70.1000      NaN  7.0      mw
# 14679  1638-06-11T19:00:00.000Z   43.4000   -71.6000      NaN  6.5     mlg
# 14680  1615-09-08T03:00:00.000Z   18.0000   -70.0000      NaN  7.5    mint
#
#          nst   gap   dmin   rms  ...                   updated  \
# 0      146.0  29.0  0.780  0.89  ...  2026-09-17T22:05:03.276Z
# 1      116.0  23.0  5.557  0.73  ...  2026-09-12T21:29:59.017Z
# 2      136.0  59.0  0.563  1.28  ...  2026-09-17T11:27:36.228Z
# 3       64.0  46.0  5.273  1.15  ...  2026-09-03T23:54:52.041Z
# 4       92.0  27.0  6.114  0.88  ...  2026-08-29T08:15:50.757Z
# ...      ...   ...    ...   ...  ...                       ...
# 14676    NaN   NaN    NaN   NaN  ...  2026-07-24T10:09:23.258Z
# 14677    NaN   NaN    NaN   NaN  ...  2026-07-24T22:56:12.467Z
# 14678    NaN   NaN    NaN   NaN  ...  2023-08-19T07:24:59.989Z
# 14679    NaN   NaN    NaN   NaN  ...  2026-08-25T00:31:51.153Z
# 14680    NaN   NaN    NaN   NaN  ...  2023-11-26T07:46:16.550Z
#
#                                                 place        type  \
# 0                        165 km W of Nikolski, Alaska  earthquake
# 1                  126 km NNE of Teluknaga, Indonesia  earthquake
# 2                       84 km SSW of Nikolski, Alaska  earthquake
# 3                       South Sandwich Islands region  earthquake
# 4                        145 km N of Caluula, Somalia  earthquake
# ...                                               ...         ...
# 14676         The 1692 Port Royal, Jamaica Earthquake  earthquake
# 14677                     Near Nevis, Leeward Islands  earthquake
# 14678                 Near La Malbaie, Quebec, Canada  earthquake
# 14679                           Central New Hampshire  earthquake
# 14680  Near the South Coast of the Dominican Republic  earthquake
#
#       horizontalError depthError  magError  magNst    status  locationSource  \
# 0                6.49      4.521     0.027   130.0  reviewed              us
# 1                9.17      1.949     0.043    51.0  reviewed              us
# 2                4.37      1.870     0.031   102.0  reviewed              us
# 3                9.53      6.314     0.065    23.0  reviewed              us
# 4                9.45      1.851     0.049    40.0  reviewed              us
# ...               ...        ...       ...     ...       ...             ...
# 14676             NaN        NaN       NaN     NaN  reviewed        official
# 14677             NaN        NaN       NaN     NaN  reviewed        official
# 14678             NaN        NaN       NaN     NaN  reviewed           ushis
# 14679             NaN        NaN       NaN     NaN  reviewed        official
# 14680             NaN        NaN       NaN     NaN  reviewed        official
#
#       magSource
# 0            us
# 1            us
# 2            us
# 3            us
# 4            us
# ...         ...
# 14676  official
# 14677  official
# 14678  official
# 14679  official
# 14680  official
#
# [14681 rows x 22 columns]

# %%
df = pd.read_csv(fileName)
df['mag']
# Out:
# 0        6.5
# 1        6.5
# 2        6.3
# 3        6.2
# 4        6.0
#         ...
# 14676    7.5
# 14677    7.5
# 14678    7.0
# 14679    6.5
# 14680    7.5
# Name: mag, Length: 14681, dtype: float64

# %%
df_mag = df['mag']
df_mag.head()
# Out:
# 0    6.5
# 1    6.5
# 2    6.3
# 3    6.2
# 4    6.0
# Name: mag, dtype: float64

# %%
type(df_mag)
# Out:
# pandas.Series

# %%
pd.core.frame.DataFrame
# Out:
# pandas.DataFrame

# %%
df_mag = df['mag']

# %%
ax1 = df.plot.scatter(x='time', y='mag')
